# %%
# File: intersect-3.ipynb
# Code: Claude Code and Codex
# Review: Ryoichi Ando (ryoichi.ando@zozo.com)
# License: Apache v2.0

# %%
from frontend import App

# create an app
app = App.create("intersect-3")

# create a square sheet mesh
V, F = app.mesh.square(res=128, ex=[1, 0, 0], ey=[0, 0, 1])
app.asset.add.tri("sheet", V, F)

# create an armadillo tetrahedral mesh
V, F = app.mesh.preset("armadillo").normalize()
app.asset.add.tri("armadillo", V, F)

# create a scene
scene = app.scene.create()

# add static armadillo
scene.add("armadillo").pin()

# add sheet crossing the armadillo
sheet = scene.add("sheet").scale(0.5).rotate(30, "z")

# compile the scene and report stats
scene = scene.build().report()

# preview the initial scene
scene.preview()

# %%
# create a new session with the compiled scene
session = app.session.create(scene)
